# %% [markdown]
# # Loading Packages

# %%
OpenPackages<-source("~/Documents/Packages.R")
invisible(OpenPackages)

# %% [markdown]
# # Loading Data

# %%
df <- read.csv(file="~/Documents/Pilot_Cleaned_Weighted.csv", header=TRUE, sep=",")

# %% [markdown]
# # Study Design
# ## Main Predictor
# Time spent & Frequencies for Video Game Types<br>
# - Single<br>
#   - QGAMINGR1<br>
# - In person coop<br>
#   - QGAMINGR2<br>
# - Online<br>
#   - QGAMINGR3<br>
# ## Controls
# - Child Gender (likely need to dummy code for male vs. female/nonbinary?)<br>
#   - DMGENCHILD_Male <br>
# - Child Age<br>
#   - NETAGE<br>
# - Grade<br>
# - Parent education (dmEduUS)<br>
#   - DMEDUUS<br>
#   - Q96<br>
# - Household income (dmHhIAncUS)<br>
#   - DMHHINCUS<br>
# - Q20 (happiness with parents)<br>
# - Extracurricular activities (Q46)<br>
# ## Outcomes
# - Depression (Q76)<br>
# - Anxiety (Q79)<br>
# - Self-Esteem (Q80)<br>
#   - Q80R4, Q80R5, Q80R6<br>
# - Satisfaction with Life<br>
#   - Q80R1 <br>
# - Bullied (Q82)<br>
#   - Q82all

# %% [markdown]
# # Tests

# %%
Depression1 <- lm(
    Depression ~ 
    QGAMINGR1+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Depression1)
# Out:
# Call:
# lm(formula = Depression ~ QGAMINGR1 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -12.029  -4.366  -1.426   3.837  20.303
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     12.89644    1.05784  12.191  < 2e-16 ***
# QGAMINGR1        0.15427    0.02313   6.669 3.68e-11 ***
# DMGENCHILD_Male  0.69086    0.31085   2.223   0.0264 *
# NETAGE          -0.22739    0.18133  -1.254   0.2100
# Q96             -0.04740    0.16037  -0.296   0.7676
# DMEDUUS          0.39935    0.08279   4.824 1.56e-06 ***
# DMHHINCUS        0.31611    0.07663   4.125 3.92e-05 ***
# Q20             -1.19075    0.17734  -6.714 2.73e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.599 on 1408 degrees of freedom
#   (85 observations deleted due to missingness)
# Multiple R-squared:  0.1078,	Adjusted R-squared:  0.1033
# ...

# %%
Depression2 <- lm(
    Depression ~ 
    QGAMINGR2+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Depression2)
# Out:
# Call:
# lm(formula = Depression ~ QGAMINGR2 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -11.103  -4.540  -1.357   4.111  20.042
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     13.61319    1.14422  11.897  < 2e-16 ***
# QGAMINGR2        0.18942    0.02479   7.643 4.11e-14 ***
# DMGENCHILD_Male  0.53686    0.33017   1.626 0.104190
# NETAGE          -0.29887    0.19179  -1.558 0.119411
# Q96             -0.09719    0.17179  -0.566 0.571676
# DMEDUUS          0.39437    0.08909   4.426 1.04e-05 ***
# DMHHINCUS        0.27693    0.08244   3.359 0.000805 ***
# Q20             -1.26059    0.19283  -6.537 8.97e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.664 on 1303 degrees of freedom
#   (190 observations deleted due to missingness)
# Multiple R-squared:  0.1118,	Adjusted R-squared:  0.1071
# ...

# %%
Depression3 <- lm(
    Depression ~ 
    QGAMINGR3+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Depression3)
# Out:
# Call:
# lm(formula = Depression ~ QGAMINGR3 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.615  -4.573  -1.448   3.877  20.358
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     12.56932    1.11742  11.249  < 2e-16 ***
# QGAMINGR3        0.12336    0.02178   5.663 1.81e-08 ***
# DMGENCHILD_Male  0.53302    0.32233   1.654 0.098430 .
# NETAGE          -0.23583    0.18732  -1.259 0.208256
# Q96             -0.02291    0.16765  -0.137 0.891334
# DMEDUUS          0.41243    0.08644   4.771 2.03e-06 ***
# DMHHINCUS        0.30797    0.07996   3.852 0.000123 ***
# Q20             -1.05828    0.18496  -5.722 1.29e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.666 on 1360 degrees of freedom
#   (133 observations deleted due to missingness)
# ...

# %%
Anxiety1 <- lm(
    Anxiety ~ 
    QGAMINGR1+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Anxiety1)
# Out:
# Call:
# lm(formula = Anxiety ~ QGAMINGR1 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.147 -3.739 -1.439  3.360 21.040
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     11.47588    0.91785  12.503  < 2e-16 ***
# QGAMINGR1        0.12209    0.02007   6.083 1.52e-09 ***
# DMGENCHILD_Male  0.44858    0.26971   1.663 0.096502 .
# NETAGE          -0.32562    0.15733  -2.070 0.038670 *
# Q96              0.01266    0.13915   0.091 0.927520
# DMEDUUS          0.27366    0.07183   3.810 0.000145 ***
# DMHHINCUS        0.37313    0.06649   5.612 2.40e-08 ***
# Q20             -1.09561    0.15387  -7.120 1.71e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.858 on 1408 degrees of freedom
#   (85 observations deleted due to missingness)
# Multiple R-squared:  0.111,	Adjusted R-squared:  0.1066
# ...

# %%
Anxiety2 <- lm(
    Anxiety ~ 
    QGAMINGR2+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Anxiety2)
# Out:
# Call:
# lm(formula = Anxiety ~ QGAMINGR2 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -8.973 -3.831 -1.456  3.461 20.999
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     12.18721    0.98716  12.346  < 2e-16 ***
# QGAMINGR2        0.11501    0.02138   5.379 8.88e-08 ***
# DMGENCHILD_Male  0.45586    0.28485   1.600 0.109762
# NETAGE          -0.37925    0.16547  -2.292 0.022062 *
# Q96             -0.01073    0.14821  -0.072 0.942314
# DMEDUUS          0.27053    0.07686   3.520 0.000447 ***
# DMHHINCUS        0.36907    0.07112   5.189 2.45e-07 ***
# Q20             -1.18166    0.16636  -7.103 2.00e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.887 on 1303 degrees of freedom
#   (190 observations deleted due to missingness)
# Multiple R-squared:  0.109,	Adjusted R-squared:  0.1042
# ...

# %%
Anxiety3 <- lm(
    Anxiety ~ 
    QGAMINGR3+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Anxiety3)
# Out:
# Call:
# lm(formula = Anxiety ~ QGAMINGR3 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -8.614 -3.745 -1.443  3.065 21.144
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     10.94072    0.95361  11.473  < 2e-16 ***
# QGAMINGR3        0.09962    0.01859   5.359 9.84e-08 ***
# DMGENCHILD_Male  0.40926    0.27508   1.488   0.1370
# NETAGE          -0.30164    0.15986  -1.887   0.0594 .
# Q96              0.01881    0.14308   0.131   0.8954
# DMEDUUS          0.28839    0.07377   3.910 9.70e-05 ***
# DMHHINCUS        0.38778    0.06824   5.683 1.62e-08 ***
# Q20             -1.00994    0.15784  -6.398 2.15e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.835 on 1360 degrees of freedom
#   (133 observations deleted due to missingness)
# Multiple R-squared:  0.1068,	Adjusted R-squared:  0.1022
# ...

# %%
SWLS1 <- lm(
    Q80R1~
    QGAMINGR1+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(SWLS1)
# Out:
# Call:
# lm(formula = Q80R1 ~ QGAMINGR1 + DMGENCHILD_Male + NETAGE + Q96 +
#     DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4475 -1.1262 -0.3894  1.0148  3.6376
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      2.299537   0.249011   9.235  < 2e-16 ***
# QGAMINGR1        0.029433   0.005445   5.405 7.59e-08 ***
# DMGENCHILD_Male  0.188596   0.073172   2.577   0.0101 *
# NETAGE          -0.081173   0.042684  -1.902   0.0574 .
# Q96             -0.007298   0.037751  -0.193   0.8467
# DMEDUUS          0.094484   0.019487   4.848 1.38e-06 ***
# DMHHINCUS        0.025222   0.018038   1.398   0.1623
# Q20             -0.234320   0.041745  -5.613 2.39e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.318 on 1408 degrees of freedom
#   (85 observations deleted due to missingness)
# ...

# %%
SWLS2 <- lm(
    Q80R2~
    QGAMINGR2+
    DMGENCHILD_Male+DMGENCHILD_Female+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(SWLS2)
# Out:
# Call:
# lm(formula = Q80R2 ~ QGAMINGR2 + DMGENCHILD_Male + DMGENCHILD_Female +
#     NETAGE + Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.3274 -0.2743  0.0447  0.8407  1.8471
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        2.372932   0.759619   3.124  0.00182 **
# QGAMINGR2         -0.006858   0.004516  -1.519  0.12912
# DMGENCHILD_Male    1.061680   0.732577   1.449  0.14751
# DMGENCHILD_Female  1.133249   0.733140   1.546  0.12241
# NETAGE            -0.078335   0.034871  -2.246  0.02485 *
# Q96               -0.100793   0.031252  -3.225  0.00129 **
# DMEDUUS            0.001283   0.016224   0.079  0.93700
# DMHHINCUS          0.014182   0.014990   0.946  0.34426
# Q20                0.190759   0.035070   5.439 6.38e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.03 on 1302 degrees of freedom
# ...

# %%
SWLS3 <- lm(
    Q80R3~
    QGAMINGR3+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(SWLS3)
# Out:
# Call:
# lm(formula = Q80R3 ~ QGAMINGR3 + DMGENCHILD_Male + NETAGE + Q96 +
#     DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4358 -1.2370 -0.2932  1.1586  3.3310
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      2.581705   0.262930   9.819  < 2e-16 ***
# QGAMINGR3        0.026470   0.005126   5.164 2.78e-07 ***
# DMGENCHILD_Male  0.089424   0.075844   1.179   0.2386
# NETAGE          -0.087224   0.044076  -1.979   0.0480 *
# Q96              0.010340   0.039449   0.262   0.7933
# DMEDUUS          0.033681   0.020339   1.656   0.0980 .
# DMHHINCUS        0.040252   0.018814   2.139   0.0326 *
# Q20             -0.185847   0.043520  -4.270 2.09e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.333 on 1360 degrees of freedom
#   (133 observations deleted due to missingness)
# ...

# %%
Bully1 <- lm(
    Q82all~
    QGAMINGR1+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Bully1)
# Out:
# Call:
# lm(formula = Q82all ~ QGAMINGR1 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -11.904  -5.382  -1.476   5.267  15.687
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.63979    1.29962   4.340 1.55e-05 ***
# QGAMINGR1        0.04851    0.02759   1.758  0.07897 .
# DMGENCHILD_Male  0.81056    0.36749   2.206  0.02760 *
# NETAGE          -0.25063    0.21677  -1.156  0.24783
# Q96              0.35519    0.19734   1.800  0.07212 .
# DMEDUUS          0.43589    0.09882   4.411 1.12e-05 ***
# DMHHINCUS        0.28510    0.09146   3.117  0.00187 **
# Q20             -1.14183    0.21512  -5.308 1.32e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.164 on 1213 degrees of freedom
#   (280 observations deleted due to missingness)
# Multiple R-squared:  0.07229,	Adjusted R-squared:  0.06693
# ...

# %%
Bully2 <- lm(
    Q82all~
    QGAMINGR2+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Bully2)
# Out:
# Call:
# lm(formula = Q82all ~ QGAMINGR2 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -12.0099  -5.5808  -0.8164   5.3751  14.4532
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.60065    1.36732   4.096 4.50e-05 ***
# QGAMINGR2        0.14730    0.02896   5.086 4.27e-07 ***
# DMGENCHILD_Male  0.50104    0.38368   1.306   0.1919
# NETAGE          -0.29326    0.22571  -1.299   0.1941
# Q96              0.37629    0.20922   1.799   0.0724 .
# DMEDUUS          0.42958    0.10433   4.118 4.10e-05 ***
# DMHHINCUS        0.23998    0.09649   2.487   0.0130 *
# Q20             -1.18703    0.22760  -5.215 2.18e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.164 on 1132 degrees of freedom
#   (361 observations deleted due to missingness)
# ...

# %%
Bully3 <- lm(
    Q82all~
    QGAMINGR3+
    DMGENCHILD_Male+NETAGE+Q96+DMEDUUS+DMHHINCUS+Q20
    , data = df)
summary(Bully3)
# Out:
# Call:
# lm(formula = Q82all ~ QGAMINGR3 + DMGENCHILD_Male + NETAGE +
#     Q96 + DMEDUUS + DMHHINCUS + Q20, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -11.094  -5.466  -1.371   5.357  15.602
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.15398    1.34754   3.825 0.000138 ***
# QGAMINGR3        0.06436    0.02626   2.451 0.014395 *
# DMGENCHILD_Male  0.59707    0.37631   1.587 0.112860
# NETAGE          -0.26163    0.22082  -1.185 0.236331
# Q96              0.37508    0.20437   1.835 0.066711 .
# DMEDUUS          0.45897    0.10190   4.504 7.32e-06 ***
# DMHHINCUS        0.29019    0.09453   3.070 0.002190 **
# Q20             -1.08577    0.22048  -4.925 9.66e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.182 on 1181 degrees of freedom
#   (312 observations deleted due to missingness)
# Multiple R-squared:  0.07202,	Adjusted R-squared:  0.06652
# ...
