# %%
# importing packages
import pandas as pd
import numpy as np
import os
import platform
import pingouin as pg
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels as sm
import pyreadstat

# %%
#opening file
df=pd.read_csv("PilotData/12012019/12012019_Merged.csv", low_memory=False)

# %%
#checking file
df
# Out:
#        coordinates                      created_at  \
# 0              NaN  Sun Dec 01 00:00:02 +0000 2019
# 1              NaN  Sun Dec 01 00:00:01 +0000 2019
# 2              NaN  Sun Dec 01 00:00:00 +0000 2019
# 3              NaN  Sun Dec 01 00:00:00 +0000 2019
# 4              NaN  Sun Dec 01 00:00:00 +0000 2019
# ...            ...                             ...
# 591785         NaN  Sun Dec 01 23:59:57 +0000 2019
# 591786         NaN  Sun Dec 01 23:59:59 +0000 2019
# 591787         NaN  Sun Dec 01 23:59:56 +0000 2019
# 591788         NaN  Sun Dec 01 23:59:58 +0000 2019
# 591789         NaN  Sun Dec 01 23:59:56 +0000 2019
#
#                                                  hashtags  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                  ImpeachTheMFTraitorNow
# 4                                                     NaN
# ...                                                   ...
# 591785                                                NaN
# 591786                                                NaN
# 591787                                                NaN
# 591788                                                NaN
# 591789  QuidProJoe Joe30330 GeritolJoe CreepyUncleJoe ...
#
#                                                     media urls  \
# 0                                                     NaN  NaN
# 1                                                     NaN  NaN
# 2                                                     NaN  NaN
# 3                                                     NaN  NaN
# 4                                                     NaN  NaN
# ...                                                   ...  ...
# 591785                                                NaN  NaN
# 591786                                                NaN  NaN
# 591787                                                NaN  NaN
# 591788  https://twitter.com/tuser5555/status/120128987...  NaN
# 591789                                                NaN  NaN
#
#         favorite_count                   id in_reply_to_screen_name  \
# 0                    0  1200927498504200192            KamalaHarris
# 1                    0  1200927496386035714                     NaN
# 2                    0  1200927489792626688         LeaderMcConnell
# 3                    0  1200927490434359300         realDonaldTrump
# 4                    0  1200927489821986817         realDonaldTrump
# ...                ...                  ...                     ...
# 591785               0  1201289867516424192                     NaN
# 591786               0  1201289875129094144         realDonaldTrump
# 591787               3  1201289862118170624             TaceyJean18
# 591788              87  1201289870888452097            TulsiGabbard
# 591789               0  1201289861262663680                JoeBiden
#
#         in_reply_to_status_id  in_reply_to_user_id  ... user_followers_count  \
# 0                1.200536e+18         3.035499e+07  ...                  209
# 1                         NaN                  NaN  ...                 1473
# 2                1.200774e+18         1.249982e+09  ...                    5
# 3                1.200918e+18         2.507388e+07  ...                 2246
# 4                1.200869e+18         2.507388e+07  ...                   31
# ...                       ...                  ...  ...                  ...
# 591785                    NaN                  NaN  ...                 1939
# 591786                    NaN         2.507388e+07  ...                 5508
# 591787           1.201289e+18         3.264432e+08  ...                31055
# 591788           1.201288e+18         2.663735e+07  ...                 5076
# 591789           1.200882e+18         9.390910e+05  ...                12644
#
#        user_friends_count user_listed_count    user_location  \
# 0                     186                 2              NaN
# 1                    3290                18    Manhattan, NY
# 2                     173                 0     Georgia, USA
# 3                    2108                 0              NaN
# 4                      61                 0              NaN
# ...                   ...               ...              ...
# 591785                  0                 2        Michigan
# 591786                885                40     Florida, USA
# 591787               3687               183              NaN
# 591788               5975                71              NaN
# 591789              13594                 3  Garden City, KS
#
#                   user_name  user_screen_name user_statuses_count  \
# 0            Diane Carrozza       DianeEllenC               13719
# 1          Things Trump Say    thingstrumpsay              154465
# 2                       AJS    AndrewJSheldon                 209
# 3                    VAgirl           agirrrl               30890
# 4       Catherine Schuchman           greyz67                1130
# ...                     ...               ...                 ...
# 591785         Michigan Tim           lmetiva                7446
# 591786                Mabry        cherrygunk                6352
# 591787        Aarika Rhodes      AarikaRhodes               23144
# 591788      Myles tuser5555         tuser5555              328521
# 591789           Thela 4#45          thela_45               90468
#
#        user_time_zone                          user_urls user_verified
# 0                 NaN                                NaN         False
# 1                 NaN                                NaN         False
# 2                 NaN                                NaN         False
# 3                 NaN                                NaN         False
# 4                 NaN                                NaN         False
# ...               ...                                ...           ...
# 591785            NaN                                NaN         False
# 591786            NaN       https://linktr.ee/cherrygunk         False
# 591787            NaN  https://www.aarikaforcongress.com          True
# 591788            NaN                    http://PETA.org         False
# 591789            NaN                                NaN         False
#
# [591790 rows x 35 columns]

# %%
#columns, i.e., variables
df.columns
# Out:
# Index(['coordinates', 'created_at', 'hashtags', 'media', 'urls',
#        'favorite_count', 'id', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_user_id', 'lang', 'place',
#        'possibly_sensitive', 'quote_id', 'retweet_count', 'retweet_id',
#        'retweet_screen_name', 'source', 'text', 'tweet_url', 'user_created_at',
#        'user_id', 'user_default_profile_image', 'user_description',
#        'user_favourites_count', 'user_followers_count', 'user_friends_count',
#        'user_listed_count', 'user_location', 'user_name', 'user_screen_name',
#        'user_statuses_count', 'user_time_zone', 'user_urls', 'user_verified'],
#       dtype='object')

# %%
#Reviewing if tweet messages actually appear
df.text
# Out:
# 0         @KamalaHarris Why is Trump mentioned by his la...
# 1         "The men and women of our military are totally...
# 2         @senatemajldr @realDonaldTrump Yeah, not like ...
# 3                  @realDonaldTrump #ImpeachTheMFTraitorNow
# 4         @realDonaldTrump Chocolate and Trump...two of ...
#                                 ...
# 591785    Hunter Biden:\n\n-Married his brother’s widow....
# 591786                    @realDonaldTrump buffalo cracker?
# 591787    @TaceyJean18 @AndrewYang @Zach_Graumann @Paget...
# 591788    @TulsiGabbard I'm from the NorthEast so I know...
# 591789    @JoeBiden #QuidProJoe #Joe30330 #GeritolJoe #C...
# Name: text, Length: 591790, dtype: object

# %%
#Total number of unique accounts in this dataset
n=len(pd.unique(df['user_screen_name']))
n
# Out:
# 216616

# %%
#number of tweets per account
df.value_counts("user_screen_name")
# Out:
# user_screen_name
# MariaAnnColeman    795
# tuser5555          388
# HenryLikesMath     329
# GangUbi            236
# chrislongview      222
#                   ...
# Rschafs60            1
# Rshale13             1
# RsnblOne             1
# RsndyM               1
# zzzz99797            1
# Length: 216616, dtype: int64

# %%
#Filtering for @JoeBiden, @realDonaldTrump, @FoxNews, @CNN; only Joe Biden tweeted for this timeframe.
dfTarget=df.loc[df['user_screen_name'].isin(['JoeBiden','realDonaldTrump','FoxNews','CNN'])]
dfTarget
# Out:
#        coordinates                      created_at          hashtags  \
# 14124          NaN  Sun Dec 01 00:20:00 +0000 2019               NaN
# 302198         NaN  Sun Dec 01 14:40:39 +0000 2019               NaN
# 460923         NaN  Sun Dec 01 19:48:00 +0000 2019  HIV WorldAIDSDay
# 523049         NaN  Sun Dec 01 21:45:00 +0000 2019               NaN
#
#                                                     media  \
# 14124                                                 NaN
# 302198                                                NaN
# 460923                                                NaN
# 523049  https://twitter.com/JoeBiden/status/1201255903...
#
#                                                      urls  favorite_count  \
# 14124                                                 NaN           50533
# 302198                                                NaN               0
# 460923  https://medium.com/@JoeBiden/statement-from-vi...            2035
# 523049                                                NaN            9591
#
#                          id in_reply_to_screen_name  in_reply_to_status_id  \
# 14124   1200932522177122304                     NaN                    NaN
# 302198  1201149111355006976                     NaN                    NaN
# 460923  1201226459278385154                     NaN                    NaN
# 523049  1201255903498002432                     NaN                    NaN
#
#         in_reply_to_user_id  ... user_followers_count user_friends_count  \
# 14124                   NaN  ...             36168208                 48
# 302198                  NaN  ...             60153655               1105
# 460923                  NaN  ...             36169486                 48
# 523049                  NaN  ...             36169756                 48
#
#        user_listed_count   user_location  user_name  user_screen_name  \
# 14124              40085  Washington, DC  Joe Biden          JoeBiden
# 302198            156488             NaN        CNN               CNN
# 460923             40082  Washington, DC  Joe Biden          JoeBiden
# 523049             40082  Washington, DC  Joe Biden          JoeBiden
#
#        user_statuses_count user_time_zone            user_urls user_verified
# 14124                 8564            NaN  http://joebiden.com          True
# 302198              386154            NaN   http://www.cnn.com          True
# 460923                8565            NaN  http://joebiden.com          True
# 523049                8565            NaN  http://joebiden.com          True
#
# [4 rows x 35 columns]

# %%
dfTarget.value_counts("user_screen_name")
# Out:
# user_screen_name
# JoeBiden    3
# CNN         1
# dtype: int64

# %%
dfTarget.text
# Out:
# 14124     Eight years of Donald Trump will fundamentally...
# 302198    Sen. @amyklobuchar on whether there's any chan...
# 460923    Over the last 30 years, the fight against #HIV...
# 523049    Every voter counts. We need a president who is...
# Name: text, dtype: object
